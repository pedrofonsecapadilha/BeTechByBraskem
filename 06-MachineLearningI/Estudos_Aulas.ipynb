# %% [markdown]
# # Aula 01 - 01/09/2023 - Informações sobre o módulo
#
# MACHINE LEARNING I
#
# Início:   01/09/2023
#
# Término:  22/09/2023
#
# Professor: Victor Costa Brito
#
# Professor: Bruno Issamo
#
#
# Introdução sobre Data Science

# %% [markdown]
# # Aula 02 - 04/09/2023 (ex.1_ok)
#
# * Regressão Linear
# * Regressão Logística
# * Confusion Matrix
# * Threshold
#
# Biblioteca Stats Models - https://www.statsmodels.org/stable/index.html
#
# Tem como ver várias análises realizadas na regressão linear.

# %% [markdown]
# # Aula 03 - 06/09/2023 (ex.2 - Faltei) - Em andamento
#
# * Validação Cruzada
# * Regressores CV

# %% [markdown]
# # Aula 04 - 11/09/2023 (ex.3)
#
# * KNN
# * Comparativo entre mótodos

# %% [markdown]
# # Aula 05 - 13/09/2023 (ex.4)
#
# * Ferramentas Especiais
# * GridSearch
# * RandomSearch

# %% [markdown]
# # Aula 06 - 15/09/2023 (ex.5)
#
# * Árvore de Decisão
# * Árvore de Classificação
# * Árvore de Regressão
