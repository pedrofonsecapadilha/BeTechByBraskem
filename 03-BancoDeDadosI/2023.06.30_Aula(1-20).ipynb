# %% [markdown]
# # [DS-PY-006] BANCO DE DADOS I

# %% [markdown]
# # Class: 1 - Informações sobre o módulo
#
# Início: 30/06/2023
# Término: 19/07/2023
#
# Professor: Rogério Mainardes
#
# e-mail: r.otavioms@gmail.com

# %% [markdown]
# # Class: 2 - Introdução
#
# Utilidade de um banco de dados
#
# Mais sobre o PostgreSQL
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 3 - Tipos de bancos de dados
#
# Existem dois tipos principais de bancos de dados: bancos relacionais e bancos não relacionais.
#
# Principais diferenças
#
# Exemplos de bancos de dados não relacionais
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 4 - Instalação do PostgreSQL no Windows:
#
# Instalação do PostgreSQL no Windows
#
# Instalação do PostgreSQL no Linux
#
# Instalação do PostgreSQL no Mac
#
# Instalação do PostgreSQL utilizando Docker
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 5 - DDL e DML
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 6 - Databases
#
# - Inserindo bases de dados
#
# Criando um banco de dados com o comando createdb
#
# Criando um banco de dados utilizando linguagem SQL
#
# - Removendo bases de dados
#
# Removendo um banco de dados com o comando dropdb
#
# Removendo um banco de dados utilizando linguagem SQL
#
# - Referências e materiais complementares

# %% [markdown]
# # Class: 7 - Criação de tabelas
#
# Criação de tabelas
#
# Edição de tabelas
#
# Exclusão de tabelas
#
# Tipos de dados mais comuns
#
# Tipos numéricos
#
# Tipos de texto
#
# Tipos de data e hora
#
# Tipos booleanos
#
# Tipos de array
#
# Tipos especiais
#
# Default values
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 8 - Chaves primárias (Primary Keys ou PKs)
#
# Chaves primárias (Primary Keys ou PKs)
#
# Chaves estrangeiras (Foreign Keys ou FKs)
#
# Tabela de Produtos e Tabela de Categorias
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 9 - Constraints
#
# CHECK
#
# NOT NULL
#
# UNIQUE
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 10 - Inserção de dados
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 11 - Edição de dados
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 12 - Exclusão de dados
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 13 - Consultas simples
#
# O WHERE
#
# LIKE
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 14 - MER e DER
#
# Modelo de Entidade e Relacionamento (MER)
#
# O que são atributos?
#
# DER (Diagrama Entidade e Relacionamento)
#
# Praticando
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 15 - Formas normais
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 16 - JOINS
#
# INNER JOIN
#
# LEFT JOIN
#
# RIGHT JOIN
#
# FULL OUTER JOIN
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 17 - UNION
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 18 - Agregação
#
# Group By
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 19 - CAST
#
# Referências e materiais complementares

# %% [markdown]
# # Class: 20 - View
#
# Referências e materiais complementares
