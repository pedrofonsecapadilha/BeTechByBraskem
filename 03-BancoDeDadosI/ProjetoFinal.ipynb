# %% [markdown]
# # PROJETO FINAL BANCO DE DADOS I

# %% [markdown]
# Duplinha;
#
# Escolha um dataset de sua preferência (Kaggle, UCI,...);
#
# https://www.kaggle.com/datasets;
# https://archive.ics.uci.edu/datasets;
#
# Coloque-o no postgres (hmmmm... como? ...);
#
# Usando o Jupyter notebook, faça uma análise descritiva;
#
# *   Qual as tipagens das colunas?;
# *   Quantos nulos temos em cada coluna?;
# *   Quantos valores únicos temos nas colunas categoricas?;
#
# Ainda no Jupyter, faça 10 perguntas ao seu dataset e responda-as com querys;
#
# *   Qual o top 10 vendas?;
# *   Qual o top 5 clientes?;
# *   Qual medida é minoria?;
#
# Organize tudo em um HTML e entregue este relatório, lembre de se identificar;
#
# Entrega até 19/07/2023 as 23h59.

# %% [markdown]
# ### Autores:	Hugo Silva de Vasconcelos & Pedro Fonseca Padilha
#
# Data:	18/07/2023
#
# Dataset:	Livros Skoob (https://www.kaggle.com/datasets/victorstein/livros-skoob)

# %% [markdown]
# ### Carregando data_set

# %%
# !pip install pandas
# !pip install pandasql
# !pip install sqlalchemy==1.4.46

# %%
import pandas as pd
import pandasql as ps
import os

# %%
livros = pd.read_csv("base_curso/kaggle_dataset.csv")

# %%
livros.head(5)
# Out:
#                              titulo                   autor       ISBN_13  \
# 0              Orçamento sem falhas           Nath Finanças  9.786556e+12
# 1             Minha Sombria Vanessa  Kate Elizabeth Russell  9.788551e+12
# 2                          Recursão            Blake Crouch  9.788551e+12
# 3              M, o Filho do Século         Antonio Scurati  9.788551e+12
# 4  Oblivion Song: Entre Dois Mundos          Robert Kirkman  9.788551e+12
#
#       ISBN_10   ano  paginas     idioma     editora  rating  avaliacao  \
# 0  6555601566  2021      128  português  Intrínseca     0.0          0
# 1  8551006274  2020      432  português  Intrínseca     4.3          2
# 2  8551005375  2020      320  português  Intrínseca     4.4          2
# 3  855100607X  2020      816  português  Intrínseca     4.6         60
# 4  8551006258  2020      136  português  Intrínseca     4.1        166
#
#    resenha  abandonos  relendo  querem_ler  lendo  leram  \
# 0        0          0        0           1      0      0
# 1      653         48        3           6    389      2
# 2      618         22        2           6    295      2
# 3       12          1        0         951     49     55
# 4       16          0        0         376      6    184
#
#                                            descricao  \
# 0  Quando o assunto é dinheiro, não dá para achar...
# 1  Elogiado por Gillian Flynn e considerado um do...
# 2  E se um dia memórias vívidas de coisas que nun...
# 3  O romance M, o Filho do Século conta em trama ...
# 4  Mestre em traçar universos distópicos permeado...
#
#                                               genero  male  female
# 0  Economia, Finanças / Literatura Brasileira / N...    28      72
# 1  Drama / Ficção / Literatura Estrangeira / Susp...     7      93
# 2  Ficção / Ficção científica / Literatura Estran...    21      79
# 3  Biografia, Autobiografia, Memórias / História ...    37      63
# 4  Ficção / HQ, comics, mangá / Literatura Estran...    44      56

# %% [markdown]
# ### Análise Descritiva

# %%
livros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11975 entries, 0 to 11974
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   titulo      11975 non-null  object
#  1   autor       11971 non-null  object
#  2   ISBN_13     11216 non-null  float64
#  3   ISBN_10     11216 non-null  object
#  4   ano         11975 non-null  int64
#  5   paginas     11975 non-null  int64
#  6   idioma      11973 non-null  object
#  7   editora     11974 non-null  object
#  8   rating      11975 non-null  float64
#  9   avaliacao   11975 non-null  int64
#  10  resenha     11975 non-null  int64
#  11  abandonos   11975 non-null  int64
#  12  relendo     11975 non-null  int64
#  13  querem_ler  11975 non-null  int64
#  14  lendo       11975 non-null  int64
#  15  leram       11975 non-null  int64
#  16  descricao   11318 non-null  object
#  17  genero      11386 non-null  object
#  18  male        11975 non-null  int64
#  19  female      11975 non-null  int64
# dtypes: float64(2), int64(11), object(7)
# memory usage: 1.8+ MB

# %%
print("Nulos e NA's")
print(livros.isnull().sum())
print(livros.isna().sum())
# Out:
# Nulos e NA's
# titulo          0
# autor           4
# ISBN_13       759
# ISBN_10       759
# ano             0
# paginas         0
# idioma          2
# editora         1
# rating          0
# avaliacao       0
# resenha         0
# abandonos       0
# relendo         0
# querem_ler      0
# lendo           0
# leram           0
# descricao     657
# genero        589
# male            0
# female          0
# dtype: int64
# titulo          0
# autor           4
# ISBN_13       759
# ISBN_10       759
# ano             0
# paginas         0
# idioma          2
# editora         1
# rating          0
# avaliacao       0
# resenha         0
# abandonos       0
# relendo         0
# querem_ler      0
# lendo           0
# leram           0
# descricao     657
# genero        589
# male            0
# female          0
# dtype: int64

# %% [markdown]
# ### 10 perguntas respondidas com Querys
#
# 01. [Quais os 10 livros com maiores avaliações?](#id_1)
# 02. [Quais editoras possuem mais livros publicados?](#id_2)
# 03. [Quantidade de livros publicados por ano por editora](#id_3)
# 04. [Qual livro foi escrito em 1193](#id_4)
# 05. [Qual autor mais lido por gênero (Male / Female)?](#id_5)
# 06. [Quais os 10 livros com maior número de abandono?](#id_6)
# 07. [Cinco editoras com maior média de abandono](#id_7)
# 08. [Quantidade de páginas escritas por autor](#id_8)
# 09. [Ordem dos livros melhores avaliados por quantidade avaliação](#id_9)
# 10. [Melhores livros por gênero literário](#id_10)

# %% [markdown]
# 01. <a name="id_1">Quais os 10 livros com maiores avaliações?</a>

# %%
ps.sqldf("""
SELECT
  titulo,
  autor,
  avaliacao
FROM
  livros
ORDER BY
  avaliacao DESC
LIMIT
  10
""")
# Out:
#                           titulo                    autor  avaliacao
# 0           Clarice na cabeceira        Clarice Lispector        999
# 1           Clarice na Cabeceira        Clarice Lispector        999
# 2   A Solidão dos Números Primos           Paolo Giordano        998
# 3  A Ciranda das Mulheres Sábias   Clarissa Pinkola Estés        998
# 4                LIVRO DUPLICADO   Clarissa Pinkola Estés        998
# 5             Geração de valor 2  Flávio Augusto da Silva        996
# 6     A Revolta de Atlas, vol. 3                 Ayn Rand        994
# 7        Encontre Deus na Cabana            Randal Rauser        994
# 8              Garota Sem Limite      Cecily von Ziegesar        993
# 9             Corações Quebrados              Sofia Silva        989

# %% [markdown]
# 02. <a name="id_2">Quais editoras possuem mais livros publicados?</a>

# %%
ps.sqldf("""
SELECT
  editora,
  COUNT(titulo) AS qtd_livros
FROM
  livros
GROUP BY
  editora
ORDER BY
  qtd_livros DESC
LIMIT
  10
""")
# Out:
#          editora  qtd_livros
# 0          Rocco        3468
# 1        Planeta        1326
# 2     Intrínseca        1310
# 3       Sextante        1258
# 4       Universo         845
# 5         Galera         801
# 6        Editora         601
# 7       Arqueiro         579
# 8          Verus         509
# 9  HarperCollins         370

# %% [markdown]
# 03. <a name="id_3">Quantidade de livros publicados por ano por editora</a>

# %%
ps.sqldf("""
SELECT
  ano,
  editora,
  COUNT(titulo) AS qtd_livros
FROM
  livros
GROUP BY
  editora,
  ano
ORDER BY
  ano DESC,
  qtd_livros DESC
LIMIT
  10
""")
# Out:
#     ano        editora  qtd_livros
# 0  2021            The           2
# 1  2021     Intrínseca           1
# 2  2021         Galera           1
# 3  2021      Excelsior           1
# 4  2020     Intrínseca          99
# 5  2020        Editora          70
# 6  2020          Rocco          66
# 7  2020  HarperCollins          59
# 8  2020       Sextante          48
# 9  2020       Arqueiro          41

# %%
# Curiosidade: Buscando livros da editora "The"

ps.sqldf("""
SELECT
  *
FROM
  livros
WHERE
  editora = 'The'
""")
# Out:
#                       titulo                autor       ISBN_13     ISBN_10  \
# 0                        Ash  Jane Harvey-Berrick  9.786556e+12  6556360171
# 1                     Pucked       Helena Hunting  9.786556e+12  6556360260
# 2                    Corrupt     Penélope Douglas  9.781516e+12  1515903346
# 3   Série Ecoresort Preciosa          Paola Scott           NaN        None
# 4                  Long Shot         Kennedy Ryan  9.786550e+12  6550480345
# ..                       ...                  ...           ...         ...
# 94            Nunca me Deixe          J.J. McAvoy  9.788553e+12  8552923386
# 95           Tapete Vermelho           M.S. Fayes           NaN        None
# 96                    Hunter         Andy Collins  9.788553e+12  8552923440
# 97     Minha Sentença é Você        Cristina Melo           NaN        None
# 98           Apenas um Toque           M.S. Fayes  9.788553e+12  8552923025
#
#      ano  paginas     idioma editora  rating  avaliacao  resenha  abandonos  \
# 0   2021      328  português     The     5.0          1        0          0
# 1   2020      304  português     The     3.6          7        0          0
# 2   2020      480  português     The     4.0         23        2          0
# 3   2020     1189  português     The     4.5          7        1          0
# 4   2020      360  português     The     4.2        347       65         10
# ..   ...      ...        ...     ...     ...        ...      ...        ...
# 94  2018      233  português     The     3.2        104       12          2
# 95  2018      289  português     The     0.0          0        0          0
# 96  2018      140  português     The     3.7        214       38          2
# 97  2018      100  português     The     4.6         25        3          0
# 98  2018      324  português     The     4.0        340       36          7
#
#     relendo  querem_ler  lendo  leram  \
# 0         0           3      0      1
# 1         0           1      1      2
# 2         0          13      4     15
# 3         0          11      1      4
# 4         1         797     27    335
# ..      ...         ...    ...    ...
# 94        1         334      3    130
# 95        0           2      0      0
# 96        0         188      5    225
# 97        0           8      1     21
# 98        0         269      8    415
#
#                                             descricao  \
# 0   DANÇA ArmasMÚSICA BalasRITMO DorMúsica na minh...
# 1   Tendo um famoso jogador da NHL como meio-irmão...
# 2   Da autora best-seller do New York Times, Penel...
# 3   O Ecoresort Preciosa é o destino de pessoas de...
# 4   UM AMOR PROÍBIDO AMBIENTADO NO EXPLOSIVO MUNDO...
# ..                                                ...
# 94  Dorian Rhys-Gallagher acabou de perder o irmão...
# 95  Uma jovem garota brasileira resolve se aventur...
# 96  "RESGATE"Foi a primeira palavra que ouvi quand...
# 97  Isabella nunca imaginou que poderia ser tão fe...
# 98  "Quando Adam St James colocou os olhos na doce...
#
#                                                genero  male  female
# 0           Drama / Literatura Estrangeira / Romance     12      88
# 1         Erótico / Literatura Estrangeira / Romance      8      92
# 2                                            Romance      2      98
# 3                                            Romance      0     100
# 4          Ficção / Literatura Estrangeira / Romance      2      98
# ..                                                ...   ...     ...
# 94  Com tantos obstáculos entre eles, o verdadeiro...     2      98
# 95   Seria ela capaz de manter um romance onde os ...     0       0
# 96                   Literatura Brasileira / Romance      1      99
# 97   Será que a magia do Natal seria capaz de cura...     0     100
# 98         "Ficção / Literatura Brasileira / Romance      0     100
#
# [99 rows x 20 columns]

# %% [markdown]
# 04. <a name="id_4">Qual livro foi escrito em 1193</a>
#
# Constatou-se que o livro lançado em 1193 aparenta ser um erro no dataset

# %%
ps.sqldf("""
SELECT
  *
FROM
  livros
WHERE
  ano = 1193
""")
# Out:
#                      titulo               autor ISBN_13 ISBN_10   ano  \
# 0  Todas as Faces de Laurie  Mary Higgins Clark    None    None  1193
#
#    paginas     idioma editora  rating  avaliacao  resenha  abandonos  relendo  \
# 0      278  português   Rocco     3.9         28        1          0        0
#
#    querem_ler  lendo  leram  \
# 0          42      0     47
#
#                                            descricao genero  male  female
# 0  Consagrada como uma das maiores escritoras ame...           13      87

# %% [markdown]
# 05. <a name="id_5">Qual autor mais lido por gênero (Male / Female)?</a>

# %%
#Female

ps.sqldf("""
SELECT
  autor,
  COUNT(titulo) as qtd_livros
FROM
  livros
WHERE
  female = 100
GROUP by
  autor
ORDER BY
  qtd_livros DESC
LIMIT
  20
""")
# Out:
#                 autor  qtd_livros
# 0      Albert Barillé          16
# 1               Rocco          11
# 2          Jojo Moyes           4
# 3   Jodi Ellen Malpas           4
# 4       Drica Pinotti           4
# 5         Herman Koch           3
# 6          Blue Jeans           3
# 7            sextante           2
# 8        Rick Riordan           2
# 9   Priscila Gorzoni            2
# 10   Priscila Gorzoni           2
# 11             Pocoyo           2
# 12  Planeta do Brasil           2
# 13        Paola Scott           2
# 14        Mona Kasten           2
# 15        John Astrop           2
# 16        Joanna Cole           2
# 17    Inês Stanisiere           2
# 18      Cristina Melo           2
# 19  Becca Fitzpatrick           2

# %%
#Male

ps.sqldf("""
SELECT
  autor,
  COUNT(titulo) as qtd_livros
FROM
  livros
WHERE
  male = 100
GROUP by
  autor
ORDER BY
  qtd_livros DESC
LIMIT
  20
""")
# Out:
#                     autor  qtd_livros
# 0          Lucasfilm Ltd.          50
# 1       Planeta do Brasil          10
# 2                  Vários           2
# 3           startupdareal           1
# 4      William S. Hatcher           1
# 5            Wilbur Smith           1
# 6          Vários autores           1
# 7          Vários Autores           1
# 8         Vanessa Barbara           1
# 9          Tony Hillerman           1
# 10          Tavae Raioaoa           1
# 11          Tadeu Carmona           1
# 12            Susana Lara           1
# 13           Steve Barlow           1
# 14   Santiago Posteguillo           1
# 15  Rubem César Fernandes           1
# 16           Rhonda byrne           1
# 17           Paulo Coelho           1
# 18         Patricio Tapia           1
# 19      Olya Roohizadegan           1

# %% [markdown]
# 06. <a name="id_6">Quais os 10 livros com maior número de abandono?</a>

# %%
ps.sqldf("""
SELECT DISTINCT
  titulo,
  abandonos
FROM
  livros
ORDER BY
  abandonos DESC
LIMIT
  10
""")
# Out:
#                             titulo  abandonos
# 0                A Hora da Estrela        993
# 1                Não se apega, não        989
# 2                Não Se Apega, Não        989
# 3                 Não se apega não        989
# 4                        O Guarani        984
# 5          A Última Carta de Amor         979
# 6           A Última Carta de Amor        979
# 7     Assassin's Creed: Renascença        966
# 8  Harry Potter e a Câmara Secreta        954
# 9                   As Duas Torres        942

# %% [markdown]
# 07. <a name="id_7">Cinco editoras com maior média de abandono</a>

# %%
ps.sqldf("""
SELECT
  editora,
  AVG(abandonos) AS media_abandono
FROM
  livros
GROUP BY
  editora
ORDER BY
  media_abandono DESC
LIMIT
  5
""")
# Out:
#      editora  media_abandono
# 0  BestBolso      712.000000
# 1  Arqueiro,      356.000000
# 2   Gailivro      205.000000
# 3       Nova      139.625000
# 4     Martin      132.731132

# %% [markdown]
# 08. <a name="id_8">Quantidade de páginas escritas por autor</a>

# %%
ps.sqldf("""
SELECT
  autor,
  SUM(paginas) as total_paginas
FROM
  livros
GROUP BY
  autor
ORDER BY
  total_paginas DESC
LIMIT
  10
""")
# Out:
#                autor  total_paginas
# 0       Rick Riordan          36566
# 1      J.K. Rowling           25524
# 2    Stephenie Meyer          23620
# 3    Cassandra Clare          23272
# 4          Meg Cabot          22703
# 5              Rocco          21878
# 6          Anne Rice          21541
# 7        J. R. Ward           21261
# 8     Diana Gabaldon          21173
# 9  Clarice Lispector          20389

# %% [markdown]
# 09. <a name="id_9">Ordem dos livros melhores avaliados por quantidade avaliação</a>

# %%
ps.sqldf("""
SELECT
  titulo,
  autor,
  rating,
  avaliacao
FROM
  livros
ORDER BY
  avaliacao DESC,
  rating DESC
LIMIT
  25
""")
# Out:
#                            titulo                       autor  rating  \
# 0            Clarice na cabeceira           Clarice Lispector     4.3
# 1            Clarice na Cabeceira           Clarice Lispector     4.3
# 2    A Solidão dos Números Primos              Paolo Giordano     4.1
# 3   A Ciranda das Mulheres Sábias      Clarissa Pinkola Estés     4.1
# 4                 LIVRO DUPLICADO      Clarissa Pinkola Estés     4.1
# 5              Geração de valor 2     Flávio Augusto da Silva     4.3
# 6      A Revolta de Atlas, vol. 3                    Ayn Rand     4.4
# 7         Encontre Deus na Cabana               Randal Rauser     3.3
# 8               Garota Sem Limite         Cecily von Ziegesar     3.9
# 9              Corações Quebrados                 Sofia Silva     4.2
# 10              A Garota Italiana               Lucinda Riley     4.1
# 11                O Último Jurado                John Grisham     3.7
# 12                   A Toda Prova                Harlan Coben     4.3
# 13                      Selvagens                 Don Winslow     3.8
# 14            Diablo III: A Ordem                 Nate Kenyon     3.6
# 15           Apenas Por Uma Noite  J.S. Cooper / Helen Cooper     3.2
# 16          Contato de Emergência              Mary H.K. Choi     3.8
# 17          As Armas da Persuasão             Robert Cialdini     4.3
# 18                  Querida Mamãe                         BTG     4.0
# 19           A princesa prometida             William Goldman     3.8
# 20                    Me Encontre               André Aciman      3.5
# 21                   Metamorfose?               Gail Carriger     4.2
# 22                        A Febre               Megan Abbott      2.9
# 23                      Butterfly              Kathryn Harvey     4.2
# 24                          Puros            Julianna Baggott     4.0
#
#     avaliacao
# 0         999
# 1         999
# 2         998
# 3         998
# 4         998
# 5         996
# 6         994
# 7         994
# 8         993
# 9         989
# 10        988
# 11        988
# 12        987
# 13        987
# 14        986
# 15        986
# 16        985
# 17        983
# 18        983
# 19        983
# 20        983
# 21        982
# 22        977
# 23        976
# 24        976

# %% [markdown]
# 10. <a name="id_10">Melhores livros por gênero literário</a>

# %%
#Ficção
ps.sqldf("""
SELECT
  titulo,
  autor,
  genero,
  rating
FROM
  livros
WHERE
  genero LIKE '%%Ficção%%'
ORDER BY
  rating DESC
LIMIT
  25
""")
# Out:
#                                                titulo  \
# 0             Caligrafia para crianças: letra cursiva
# 1                                                Cola
# 2                                      Estas Verdades
# 3                                     A FORMA DA ÁGUA
# 4     Primeiros passos para escrever letras e números
# 5     Meu caderno de atividades do jardim de infância
# 6           Meu caderno de atividades do corpo humano
# 7             Meu caderno de atividades de matemática
# 8                  Meu primeiro caderno de atividades
# 9   Livro de coisas divertidas para encantar e col...
# 10                   Você pode ser livre onde estiver
# 11                               Lições de Estratégia
# 12                              Um Curso de Meditação
# 13                      Pai, me conta a sua história?
# 14                       Vô, me conta a sua história?
# 15                                   Culinária básica
# 16                          Corte de Chamas Prateadas
# 17         O Guia da Donzela para Anáguas e Pirataria
# 18                                        REVIRAVENTO
# 19                    Harry Potter e o Cálice de Fogo
# 20                                            A prova
# 21                                            A prova
# 22                                            A prova
# 23                         Sobreviventes e guerreiras
# 24                                 21 Nossas senhoras
#
#                       autor  \
# 0             Crystal Radke
# 1              Irvine Welsh
# 2               Jill Lepore
# 3                 Del Toro
# 4             Crystal Radke
# 5            Brittany Lynch
# 6              Katie Stokes
# 7                Keri Brown
# 8            Brittany Lynch
# 9                Highlights
# 10           Jack Kornfield
# 11  Harvard Businnes Review
# 12                     Osho
# 13           Elma van Vliet
# 14           Elma van Vliet
# 15       Vigilantes do Peso
# 16            Sarah J. Maas
# 17             Mackenzi Lee
# 18           Silvana Tavano
# 19            J.K. Rowling
# 20            Agota Kristof
# 21            Agota Kristof
# 22            Agota Kristof
# 23          Mary del Priore
# 24               Bell Kranz
#
#                                                genero  rating
# 0   Boa diversão! " - Iberê Thenório e Mari Fulfar...     7.0
# 1                                             Ficção      6.0
# 2     História / Literatura Estrangeira / Não-ficção      5.0
# 3          Ficção / Literatura Estrangeira / Romance      5.0
# 4   Boa diversão! " - Iberê Thenório e Mari Fulfar...     5.0
# 5   Boa diversão! " - Iberê Thenório & Mari Fulfar...     5.0
# 6   Educação / Infantil / Literatura Estrangeira /...     5.0
# 7   LETRAS E LEITURA  NOÇÕES DE MATEMÁTICA  CIÊN...     5.0
# 8    CORES  LETRAS  NÚMEROS  FORMAS  PADRÕES...     5.0
# 9    Aqui aprendizado é sinônimo de diversão!Anima...     5.0
# 10   Autoajuda / Literatura Estrangeira / Não-ficção      5.0
# 11   Mankins e Richard Steele"Quem toma a decisão?...     5.0
# 12  Autoajuda / Não-ficção / Religião e Espiritual...     5.0
# 13               Literatura Estrangeira / Não-ficção      5.0
# 14               Literatura Estrangeira / Não-ficção      5.0
# 15  Sinta-se no controle da sua alimentação!Culiná...     5.0
# 16                   Ficção / Literatura Estrangeira      5.0
# 17   Todos os personagens são lindamente construíd...     5.0
# 18                                 Ficção / Infantil      5.0
# 19   Será que estão preparados?Aventura / Entreten...     5.0
# 20  Aventura / Comunicação / Drama / Ficção / Hist...     5.0
# 21   Aventura / Comunicação / Drama / Ficção / His...     5.0
# 22   Aventura / Comunicação / Drama / Ficção / His...     5.0
# 23  História do Brasil / Literatura Estrangeira / ...     5.0
# 24  Literatura Brasileira / Não-ficção / Religião ...     5.0

# %%
#Distopia
ps.sqldf("""
SELECT
  titulo,
  autor,
  genero,
  rating
FROM
  livros
WHERE
  genero LIKE '%%Distopia%%'
ORDER BY
  rating DESC
LIMIT
  25
""")
# Out:
#                                                titulo              autor  \
# 0                                   Box Jogos Vorazes    Suzanne Collins
# 1                                      Estilhaça - me       Tahereh Mafi
# 2                                      Os Testamentos    Margaret Atwood
# 3                                           Em Chamas    Suzanne Collins
# 4                                       Jogos Vorazes    Suzanne Collins
# 5                                      O Conto da Aia    Margaret Atwood
# 6                                              Winter      Marissa Meyer
# 7                                               Cress      Marissa Meyer
# 8   Tudo o que você precisou desaprender para vira...     Meteoro Brasil
# 9                                        Incendeia-me       Tahereh Mafi
# 10                                            Aladdin  Elizabeth Rudnick
# 11                         A Revolta de Atlas, vol. 1           Ayn Rand
# 12                                 A Revolta de Atlas           Ayn Rand
# 13                                 A Revolta de Atlas           Ayn Rand
# 14                                     O Conto da Aia    Margaret Atwood
# 15                      Na Era do Amor e do Chocolate    Gabrielle Zevin
# 16                                           Champion           Marie Lu
# 17                                            Scarlet      Marissa Meyer
# 18                                         Divergente      Veronica Roth
# 19                                     O Conto da Aia    Margaret Atwood
# 20                             Uma Tocha na Escuridão        Sabaa Tahir
# 21                             Uma Tocha Na Escuridão        Sabaa Tahir
# 22                             A corrida de escorpião  Maggie Stiefvater
# 23                                         Desafia-me       Tahereh Mafi
# 24                                    Magia Explosiva      Ilona Andrews
#
#                                                genero  rating
# 0                      Aventura / Distopia / Romance      4.9
# 1                                Distopia / Fantasia      4.7
# 2   Distopia / Ficção científica / Literatura Estr...     4.6
# 3   Ficção / Aventura / Distopia / Literatura Estr...     4.6
# 4   Ficção / Distopia / Aventura / Literatura Estr...     4.6
# 5   Distopia / Drama / Ficção / HQ, comics, mangá ...     4.5
# 6    Será que Cinder, Scarlet, Cress e Winter pode...     4.5
# 7   Distopia / Ficção científica / Jovem adulto / ...     4.5
# 8    Com a mesma clareza e didática dos seus mais ...     4.5
# 9   Aventura / Distopia / Ficção / Ficção científi...     4.5
# 10   Será que ele será bem-sucedido nessa aventura...     4.5
# 11  Distopia / Drama / Ficção / Literatura Estrang...     4.4
# 12  Distopia / Drama / Ficção / Literatura Estrang...     4.4
# 13  Distopia / Drama / Ficção / Literatura Estrang...     4.4
# 14                                          Distopia      4.4
# 15                  Ficção / Distopia / Jovem adulto      4.4
# 16  Distopia / Jovem adulto / Literatura Estrangeira      4.4
# 17  Distopia / Ficção científica / Jovem adulto / ...     4.4
# 18  Literatura Estrangeira / Ficção / Distopia / I...     4.4
# 19                                          Distopia      4.4
# 20   Mas como matar alguém que você ama desesperad...     4.4
# 21   Mas como matar alguém que você ama desesperad...     4.4
# 22                               Distopia / Fantasia      4.4
# 23  Distopia / Fantasia / Ficção científica / Jove...     4.4
# 24   Louco Rogan e Nevada Baylor precisarão, para ...     4.4

# %%
#Horror
ps.sqldf("""
SELECT
  titulo,
  autor,
  genero,
  rating
FROM
  livros
WHERE
  genero LIKE '%%Distopia%%'
ORDER BY
  rating DESC
LIMIT
  25
""")
# Out:
#                                                titulo              autor  \
# 0                                   Box Jogos Vorazes    Suzanne Collins
# 1                                      Estilhaça - me       Tahereh Mafi
# 2                                      Os Testamentos    Margaret Atwood
# 3                                           Em Chamas    Suzanne Collins
# 4                                       Jogos Vorazes    Suzanne Collins
# 5                                      O Conto da Aia    Margaret Atwood
# 6                                              Winter      Marissa Meyer
# 7                                               Cress      Marissa Meyer
# 8   Tudo o que você precisou desaprender para vira...     Meteoro Brasil
# 9                                        Incendeia-me       Tahereh Mafi
# 10                                            Aladdin  Elizabeth Rudnick
# 11                         A Revolta de Atlas, vol. 1           Ayn Rand
# 12                                 A Revolta de Atlas           Ayn Rand
# 13                                 A Revolta de Atlas           Ayn Rand
# 14                                     O Conto da Aia    Margaret Atwood
# 15                      Na Era do Amor e do Chocolate    Gabrielle Zevin
# 16                                           Champion           Marie Lu
# 17                                            Scarlet      Marissa Meyer
# 18                                         Divergente      Veronica Roth
# 19                                     O Conto da Aia    Margaret Atwood
# 20                             Uma Tocha na Escuridão        Sabaa Tahir
# 21                             Uma Tocha Na Escuridão        Sabaa Tahir
# 22                             A corrida de escorpião  Maggie Stiefvater
# 23                                         Desafia-me       Tahereh Mafi
# 24                                    Magia Explosiva      Ilona Andrews
#
#                                                genero  rating
# 0                      Aventura / Distopia / Romance      4.9
# 1                                Distopia / Fantasia      4.7
# 2   Distopia / Ficção científica / Literatura Estr...     4.6
# 3   Ficção / Aventura / Distopia / Literatura Estr...     4.6
# 4   Ficção / Distopia / Aventura / Literatura Estr...     4.6
# 5   Distopia / Drama / Ficção / HQ, comics, mangá ...     4.5
# 6    Será que Cinder, Scarlet, Cress e Winter pode...     4.5
# 7   Distopia / Ficção científica / Jovem adulto / ...     4.5
# 8    Com a mesma clareza e didática dos seus mais ...     4.5
# 9   Aventura / Distopia / Ficção / Ficção científi...     4.5
# 10   Será que ele será bem-sucedido nessa aventura...     4.5
# 11  Distopia / Drama / Ficção / Literatura Estrang...     4.4
# 12  Distopia / Drama / Ficção / Literatura Estrang...     4.4
# 13  Distopia / Drama / Ficção / Literatura Estrang...     4.4
# 14                                          Distopia      4.4
# 15                  Ficção / Distopia / Jovem adulto      4.4
# 16  Distopia / Jovem adulto / Literatura Estrangeira      4.4
# 17  Distopia / Ficção científica / Jovem adulto / ...     4.4
# 18  Literatura Estrangeira / Ficção / Distopia / I...     4.4
# 19                                          Distopia      4.4
# 20   Mas como matar alguém que você ama desesperad...     4.4
# 21   Mas como matar alguém que você ama desesperad...     4.4
# 22                               Distopia / Fantasia      4.4
# 23  Distopia / Fantasia / Ficção científica / Jove...     4.4
# 24   Louco Rogan e Nevada Baylor precisarão, para ...     4.4
