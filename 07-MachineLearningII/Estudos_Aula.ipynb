# %% [markdown]
# # 25/09/2023 - Aula 01 (Ex - OK)
#
# Professor: Bruno Issamo
#
# 2 Projetos (Supervisionado + Não Supervisionado)
# * 02/10 - Projeto 01
# * 11/10 - Projeto 02

# %% [markdown]
# # 27/09/2023 - Aula 02 (Ex - OK)
#
# * SVM

# %% [markdown]
# # 29/09/2023 - Aula 03 (Ex - OK)
#
# * SVM (finalizou a última aula)
# * Métodos de Ensemble
#   - Bagging
#   - Boosting (Adaboost / Gradient Boosting / XGBoost)
#   - Stacking

# %% [markdown]
# # 02/10/2023 - Aula 04 (Ex - N/A)
#
# * Aprendizagem não-supervisionada
# * Clusterização
# * Redução de dimensionalidade

# %% [markdown]
# ## Recados
#
# - Quinta feira (05/10/2023 - 19h): pitch de sucesso (ADA + Braskem)
# - 17-18/10/2023: Feira de Empregabilidade
# - Formulário do Evento: https://adatech.typeform.com/to/s8Xx0BAC#tc=233&mod=%20&what=Confirma%C3%A7%C3%A3o%20interesse%20na%20feira%20Speed%20Hiring&type=1

# %% [markdown]
# # 04/10/2023 - Aula 05 (Ex - OK)
#
# * Apresentação do Projeto Supervisionado
# * K-means

# %% [markdown]
# # 05/10/2023 - Evento Pitch

# %% [markdown]
# # 06/10/2023 - Aula 06 (Ex - OK)
#
# * K-means (Final da aula 05)
# * DBSCAN

# %% [markdown]
# # 09/10/2023 - Aula 07 (Ex - N/A)
#
# * DBSCAN + KMEANS (Atividade Aula 06)
# * Agrupamento Hierárquico (Aglomerando para Conquistar)

# %% [markdown]
# # 11/10/2023 - Aula 08 (Ex - OK)
#
# * Agrupamento Hierárquico (Aglomerando para Conquistar) - Continuação

# %% [markdown]
# # 16/10/2023 - Aula 09 (Ex - N/A)
#
# * Apresentação do Projeto Não Supervisionado
