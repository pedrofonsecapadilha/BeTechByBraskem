# %% [markdown]
# # 25/09/2023 - Aula 01 (Ex - OK)
#
# Professor: Bruno Issamo
#
# 2 Projetos (Supervisionado + Não Supervisionado)
# * 02/10 - Projeto 01
# * 11/10 - Projeto 02

# %% [markdown]
# # 27/09/2023 - Aula 02 (Ex - OK)
#
# * SVM

# %% [markdown]
# # 29/09/2023 - Aula 03 (Ex - ) **FALTEI - VER AULA + EX**
#
#
# Resp.: Exercício Sala
# AdaBoost = 0.95 | 0.77
# GradientBoosting = 0.75 | 0.84
# XGBoost = 0.95 | 0.82

# %% [markdown]
# # 02/10/2023 - Aula 04 (Ex - N/A)
#
# * Aprendizagem não-supervisionada
# * Clusterização
# * Redução de dimensionalidade

# %% [markdown]
# ## RECADOS
#
# - Quinta feira (05/10/2023 - 19h): pitch de sucesso (ADA + Braskem)
# - 17-18/10/2023: Feira de Empregabilidade
# - Formulário do Evento: https://adatech.typeform.com/to/s8Xx0BAC#tc=233&mod=%20&what=Confirma%C3%A7%C3%A3o%20interesse%20na%20feira%20Speed%20Hiring&type=1
#
# Discord - Enviar mensagem para Thiago sobre intenção de contratação da Braskem

# %% [markdown]
# # 04/10/2023 - Aula 05 (Ex - ) **FALTEI - VER AULA + EX**

# %% [markdown]
# # 05/10/2023 - Evento Pitch **FALTEI - VER AULA**
